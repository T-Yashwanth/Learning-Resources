# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

sentences = [
    "That is a happy person",
    "That is a happy dog",
    "That is a very happy person",
    "Today is a sunny day"
]
embeddings = model.encode(sentences)

#similarities = model.similarity(embeddings, embeddings)
#print(similarities.shape)
# [4, 4]

# %%
embeddings.shape
# Out:
# (4, 384)

# %%
embeddings[0].shape
# Out:
# (384,)

# %%
import pinecone
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pinecone
#
# File c:\Users\yash\anaconda3\envs\Genai\lib\site-packages\pinecone\__init__.py:5
#       1 """
#       2 .. include:: ../README.md
#       3 """
# ----> 5 raise Exception(
#       6     "The official Pinecone python package has been renamed from `pinecone-client` to `pinecone`. Please remove `pinecone-client` from your project dependencies and add `pinecone` instead. See the README at https://github.com/pinecone-io/pinecone-python-client for more information on using the python SDK."
#       7 )
#
# ...

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
# Initialize Pinecone
pc = Pinecone(api_key='pcsk_6RL3cw_SL91DaiYsvgecF1ZcWieyhERCoDrFfKyocPXmVcsE6GMicMCCMnNpj1wxYDxenY')

# %%
index_name = "firstvectors"

# %%
# Create Pinecone index if it doesn't exist
# The dimension should match your model's output dimension (384 for all-MiniLM-L6-v2)
if not pc.has_index(index_name):
    pc.create_index(
        name=index_name,
        dimension=384,  # dimension for all-MiniLM-L6-v2
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )

# %%
# Connect to the index
index = pc.Index(index_name)

# %%
vector_to_upsert = []
for idx, (sentence, embedding) in enumerate(zip(sentences, embeddings)):
    vector_to_upsert.append({
        'id': f'vec_{idx}',
        'values': embedding,
        'metadata':{
            'text':sentence
        }
    })

# %%
vector_to_upsert
# Out:
# [{'id': 'vec_0',
#   'values': array([-3.38769071e-02,  9.19416472e-02,  4.87013571e-02, -3.48835215e-02,
#          -6.48292154e-02, -2.66857576e-02,  1.34293407e-01, -6.91495975e-03,
#           6.44349456e-02, -5.82767604e-03,  8.87372568e-02, -1.62496530e-02,
#          -2.54945923e-02,  4.83909389e-03,  6.14896510e-03,  1.55436713e-02,
#          -5.95202409e-02, -3.20247822e-02,  1.41185448e-02,  2.05606339e-03,
#          -1.00310959e-01, -2.04246608e-03, -2.08596233e-02,  9.96046513e-03,
#          -1.69836096e-02, -1.64659619e-02,  4.00910750e-02, -2.72047613e-03,
#           8.66090804e-02,  6.33227527e-02, -2.68441234e-02, -2.35456396e-02,
#           1.09181762e-01,  2.25531682e-02, -3.85773145e-02,  1.94851607e-02,
#          -3.15519758e-02,  1.68708470e-02, -9.62979719e-03,  2.02890690e-02,
#          -1.82442069e-02,  1.77636892e-02,  1.86448190e-02,  1.22921783e-02,
#          -2.05465150e-03, -3.49595845e-02,  6.22536577e-02, -4.34290878e-02,
# ...

# %%
# Upsert vectors to Pinecone
index.upsert(
    vectors=vector_to_upsert,
    namespace="example-array"
)
# Out:
# {'upserted_count': 4}

# %%
-0.0338769071,0.0919416472,0.0487013571,-0.0348835215,-0.0648292154,-0.0266857576,0.134293407,-0.00691495975,0.0644349456,-0.00582767604,0.0887372568,-0.016249653,-0.0254945923,0.00483909389,0.0061489651,0.0155436713,-0.0595202409,-0.0320247822,0.0141185448,0.00205606339,-0.100310959,-0.00204246608,-0.0208596233,0.00996046513,-0.0169836096,-0.0164659619,0.040091075,-0.00272
356085226,0.0592745952,0.038811896,-0.0332118422,-0.0779239908,-0.00491811847,-0.0451407842,-0.00109362102,0.0530923232,0.0297326855,0.0274264887,-0.044077076,-0.0205070209,0.00364413951,-1.77887465e-8,-0.00456481054,-0.0497799255,-0.0679319128,-0.094125241,0.043209,0.0147966621,0.115254886,-0.106512383,-0.0301294979,0.0436999,0.0377380215,0.0490807481,0.0220075231,-0.0408374257,0.0216148198,-0.0301952399,0.108728573,-0.0107205734,-0.00704817,0.0896152928,0.0669415817,-0.01612271,0.0305078141,0.102114201,-0.0770330206,-0.00331941247,-0.0829841271,-0.0272439234,-0.0530076772,0.0437175892,0.0104870591,0.0040512518,-0.0296063107,-0.00709691038,0.0963719487,0.0706569105,0.0132733835,-0.022046525,0.0445610471,0.0743881315,-0.0534378402,0.0274968874,-0.0746115223,0.10384436,-0.0621491596,-0.0262251813,0.0356996357,-0.041294381,-0.0264705606,0.0301117599,0.0783537105,-0.00731024938,-0.0443922319,0.0853936076,-0.0358674154,-0.111069486,0.0351417959,0.0181601793,-0.0518306941,-0.0123946909,-0.00936723594,-0.0143925985,-0.0275497492,0.0447582155

# %%
# Upsert vectors to Pinecone
index.upsert(
    vectors=vector_to_upsert,
    namespace="example-namespace"
)

# Example query using the first sentence
query_embedding = model.encode(sentences[2])
query_results = index.query(
    vector=query_embedding.tolist(),
    top_k=3,
    include_metadata=True,
    namespace="example-array"
)
print(query_results)

# Print results
print("\nQuery Results:")
for match in query_results['matches']:
    print(f"ID: {match['id']}")
    print(f"Score: {match['score']}")
    print(f"Text: {match['metadata']['text']}\n")
# Out:
# {'matches': [{'id': 'vec_2',
#               'metadata': {'text': 'That is a very happy person'},
#               'score': 1.00079012,
#               'values': []},
#              {'id': 'vec_0',
#               'metadata': {'text': 'That is a happy person'},
#               'score': 0.943254292,
#               'values': []},
#              {'id': 'vec_1',
#               'metadata': {'text': 'That is a happy dog'},
#               'score': 0.620521367,
#               'values': []}],
#  'namespace': 'example-array',
#  'usage': {'read_units': 6}}
#
# Query Results:
# ID: vec_2
# Score: 1.00079012
# Text: That is a very happy person
#
# ID: vec_0
# Score: 0.943254292
# Text: That is a happy person
#
# ID: vec_1
# Score: 0.620521367
# Text: That is a happy dog

# %%
current_stats = index.describe_index_stats()
print(current_stats)
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'example-array': {'vector_count': 4},
#                 'example-namespace': {'vector_count': 4}},
#  'total_vector_count': 8,
#  'vector_type': 'dense'}

# %%
new_sentences = [
    "The weather is beautiful",
    "I love programming",
    "Machine learning is fascinating"
]

# Generate embeddings for new sentences
new_embeddings = model.encode(new_sentences)

# %%
# Prepare new vectors for upserting
new_vectors = []
for idx, (sentence, embedding) in enumerate(zip(new_sentences, new_embeddings)):
    new_vectors.append({
        'id': f'vec_{idx}',  # Continue the ID sequence
        'values': embedding.tolist(),
        'metadata': {
            'text': sentence
        }
    })

# %%
# Upsert new vectors to the same namespace
index.upsert(
    vectors=new_vectors,
    namespace="example-namespace"  # Use the same namespace as before
)
# Out:
# {'upserted_count': 3}

# %%
current_stats = index.describe_index_stats()
print(current_stats)
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'example-array': {'vector_count': 4},
#                 'example-namespace': {'vector_count': 4}},
#  'total_vector_count': 8,
#  'vector_type': 'dense'}
